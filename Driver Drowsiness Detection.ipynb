# %%
# mounting google drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # API setup

# %%
# download the tensorflow object detection API in colab directory
# %cd '/content/drive/MyDrive/Driver_Drowsiness'

clone the TensorFlow Model Garden repository
# !git clone https://github.com/tensorflow/models.git

# %%
# download the pre-trained model
import requests

model_name = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
file_url = "http://download.tensorflow.org/models/object_detection/tf2/20200711/" + model_name
    
r = requests.get(file_url, stream = True)  
  
with open("/content/drive/MyDrive/Driver_Drowsiness/workspace/training/pre-trained-models/"+ model_name, "wb") as file:  
    for block in r.iter_content(chunk_size = 1024): 
         if block:  
             file.write(block)

# %%
# Install some required libraries and tools.
# !apt-get install protobuf-compiler python-lxml python-pil
# !pip install Cython pandas tf-slim
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 16 not upgraded.
# Need to get 1,615 kB of archives.
# After this operation, 8,907 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-bs4 all 4.6.0-1 [67.9 kB]
# ...

# %%
# Compile the Protobuf libraries.
# %cd '/content/drive/MyDrive/Driver_Drowsiness/models/research/'
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/drive/MyDrive/Driver_Drowsiness/models/research

# %%
# Environment setup
import os
import sys
# !pip install lvis
os.environ['PYTHONPATH']+=":/content/drive/MyDrive/Driver_Drowsiness/models"
sys.path.append("/content/drive/MyDrive/Driver_Drowsiness/models/research")

# %%
# Install setup
# !python setup.py build
# !python setup.py install
# Out:
# running build
# running build_py
# copying object_detection/protos/bipartite_matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/square_box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/graph_rewriter_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/ssd_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/input_reader_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/faster_rcnn_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/pipeline_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/flexible_grid_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/center_net_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/image_resizer_pb2.py -> build/lib/object_detection/protos
# ...

# %%
# Testing the installation

# %cd '/content/drive/MyDrive/Driver_Drowsiness/models/research/object_detection/builders'
# !python model_builder_tf2_test.py
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
print('Done')
# Out:
# /content/drive/My Drive/Driver_Drowsiness/models/research/object_detection/builders
# 2021-01-13 03:30:45.551769: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Running tests under Python 3.6.9: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model
# 2021-01-13 03:30:57.350543: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-13 03:30:57.391666: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-13 03:30:57.475144: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %% [markdown]
# # Data Preparation

# %%
# generate tfrecord 

# %cd '/content/drive/MyDrive/Driver_Drowsiness/scripts/preprocessing'
# Out:
# /content/drive/MyDrive/Driver_Drowsiness/scripts/preprocessing

# %%
# Create csv files
# !python generate_csv.py xml /content/drive/MyDrive/Driver_Drowsiness/workspace/training/images/train /content/drive/MyDrive/Driver_Drowsiness/workspace/training/annotations/train.csv
# !python generate_csv.py xml /content/drive/MyDrive/Driver_Drowsiness/workspace/training/images/test /content/drive/MyDrive/Driver_Drowsiness/workspace/training/annotations/test.csv

# %%
# pbtxt
# !python generate_pbtxt.py csv /content/drive/MyDrive/Driver_Drowsiness/workspace/training/annotations/train.csv /content/drive/MyDrive/Driver_Drowsiness/workspace/training/annotations/label_map.pbtxt

# %%
# tfrecord
# !python generate_tfrecord.py /content/drive/MyDrive/Driver_Drowsiness/workspace/training/annotations/train.csv /content/drive/MyDrive/Driver_Drowsiness/workspace/training/annotations/label_map.pbtxt /content/drive/MyDrive/Driver_Drowsiness/workspace/training/images/train /content/drive/MyDrive/Driver_Drowsiness/workspace/training/annotations/train.tfrecords
# !python generate_tfrecord.py /content/drive/MyDrive/Driver_Drowsiness/workspace/training/annotations/test.csv /content/drive/MyDrive/Driver_Drowsiness/workspace/training/annotations/label_map.pbtxt /content/drive/MyDrive/Driver_Drowsiness/workspace/training/images/test /content/drive/MyDrive/Driver_Drowsiness/workspace/training/annotations/test.tfrecords

# %% [markdown]
# # Model Training

# %%
# start Tensorboard.
# %cd '/content/drive/MyDrive/Driver_Drowsiness/workspace/training'

# start the Tensorboard
# %load_ext tensorboard
#%tensorboard --logdir=models/my_ssd_mobilenet_v1_fpn_640
# %tensorboard --logdir=models/my_ssd_mobilenet_v2_fpnlite_320

# %%
# train the model.

#!python model_main_tf2.py --model_dir=models/my_ssd_mobilenet_v1_fpn_640 --pipeline_config_path=models/my_ssd_mobilenet_v1_fpn_640/pipeline.config
# !python model_main_tf2.py --model_dir=models/my_ssd_mobilenet_v2_fpnlite_320 --pipeline_config_path=models/my_ssd_mobilenet_v2_fpnlite_320/pipeline.config

# %% [markdown]
# # Model Export and Testing

# %%
# Model export

# %cd '/content/drive/MyDrive/Driver_Drowsiness/workspace/training'
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path /content/drive/MyDrive/Driver_Drowsiness/workspace/training/models/my_ssd_mobilenet_v2_fpnlite_320/pipeline.config --trained_checkpoint_dir /content/drive/MyDrive/Driver_Drowsiness/workspace/training/models/my_ssd_mobilenet_v2_fpnlite_320 --output_directory /content/drive/MyDrive/Driver_Drowsiness/workspace/training/exported-models/my_model/ssd_mobilenet_v2_fpnlite_320
# Out:
# /content/drive/.shortcut-targets-by-id/1k45RE-eU_acHjtI16NcsgF1SHWp8qPX2/Driver_Drowsiness/workspace/training
# 2021-01-09 12:27:04.945026: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-09 12:27:09.713920: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-09 12:27:09.714914: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-09 12:27:09.725672: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-01-09 12:27:09.725725: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (945bfdb9e6a6): /proc/driver/nvidia/version does not exist
# ...

# %%
# Load the saved_model
import tensorflow as tf
import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
PATH_TO_SAVED_MODEL="/content/drive/MyDrive/Driver_Drowsiness/workspace/training/exported-models/my_model/ssd_mobilenet_v2_fpnlite_320/saved_model"
print('Loading model...', end='')

# Load saved model and build the detection function
detect_fn=tf.saved_model.load(PATH_TO_SAVED_MODEL)
print('Done!')
# Out:
# Loading model...Done!

# %%
# Load the label_map
category_index=label_map_util.create_category_index_from_labelmap("/content/drive/MyDrive/Driver_Drowsiness/workspace/training/annotations/label_map.pbtxt",use_display_name=True)

# %%
# load test images
from os import listdir

img_path = '/content/drive/MyDrive/Driver_Drowsiness/workspace/testing/test_images/'
images = listdir(img_path)

#list containing paths of all the images
image_list = [] 
for img in images:
  image_path = img_path + img
  image_list.append(image_path) 

print(image_list)
# Out:
# ['/content/drive/MyDrive/Driver_Drowsiness/workspace/testing/test_images/img (3).jpg', '/content/drive/MyDrive/Driver_Drowsiness/workspace/testing/test_images/img (1).jpg', '/content/drive/MyDrive/Driver_Drowsiness/workspace/testing/test_images/img (6).jpg', '/content/drive/MyDrive/Driver_Drowsiness/workspace/testing/test_images/img (2).jpg', '/content/drive/MyDrive/Driver_Drowsiness/workspace/testing/test_images/img (4).jpg', '/content/drive/MyDrive/Driver_Drowsiness/workspace/testing/test_images/img (5).jpg']

# %% [markdown]
# # Object detection from saved model

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

def load_image_into_numpy_array(path):
    return np.array(Image.open(path))

for image_path in image_list:

    print('Running inference for {}... '.format(image_path), end='')
    image_np=load_image_into_numpy_array(image_path)

    # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
    input_tensor=tf.convert_to_tensor(image_np)
    # The model expects a batch of images, so add an axis with `tf.newaxis`.
    input_tensor=input_tensor[tf.newaxis, ...]

    # input_tensor = np.expand_dims(image_np, 0)
    detections=detect_fn(input_tensor)

    # All outputs are batches tensors.
    # Convert to numpy arrays, and take index [0] to remove the batch dimension.
    # We're only interested in the first num_detections.
    num_detections=int(detections.pop('num_detections'))
    detections={key:value[0,:num_detections].numpy()
                   for key,value in detections.items()}
    detections['num_detections']=num_detections

    # detection_classes should be ints.
    detections['detection_classes']=detections['detection_classes'].astype(np.int64)

    image_np_with_detections=image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
          image_np_with_detections,
          detections['detection_boxes'],
          detections['detection_classes'],
          detections['detection_scores'],
          category_index,
          use_normalized_coordinates=True,
          max_boxes_to_draw=4,     #max number of bounding boxes in the image
          min_score_thresh=.3,      #min prediction threshold
          agnostic_mode=False)
    # %matplotlib inline
    plt.figure(figsize=(15,15))
    plt.imshow(image_np_with_detections)
    print('Done')
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Detect Objects Using Webcam + Alert
#
# - Tried on Windows local machine

# %%
# Alert sound (Compatible with windows only)
import winsound
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second

# %%
# Capture video
import cv2

#cap = cv2.VideoCapture('/content/drive/MyDrive/Driver_Drowsiness/workspace/testing/vid1.mp4')
cap = cv2.VideoCapture(0)

# %%
# Alarm alert and webcame inference
counter = 0
alarm_on = False

while True:
    # Read frame from camera
    ret, image_np = cap.read()

    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)

    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.uint8)
    detections = detect_fn(input_tensor)
    label_id_offset = 1
    image_np_with_detections = image_np.copy()
    
    viz_utils.visualize_boxes_and_labels_on_image_array(
          image_np_with_detections,
          detections['detection_boxes'][0].numpy(),
          (detections['detection_classes'][0].numpy() + label_id_offset).astype(int),
          detections['detection_scores'][0].numpy(),
          category_index,
          use_normalized_coordinates=True,
          max_boxes_to_draw=1,
          min_score_thresh=.30,
          agnostic_mode=False)

    # Display output
    cv2.imshow('object detection', cv2.resize(image_np_with_detections, (800, 600)))
    
    # Beep sound if approximately 5 sec driver feels drowsiness
    current_cls = (detections['detection_classes'][0].numpy()[0] + label_id_offset).astype(int)
    if current_cls==1:                  # 1:'closed', 2:'open'
        counter += 1
        if counter >= 35:               # used 7FPS, for 5sec it takes around 35 frame to creat alarm if class 'closed'
            if not alarm_on:
                alarm_on=True
                winsound.Beep(frequency, duration)
    else:
        counter=0
        alarm_on=False
            
    if cv2.waitKey(150) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
